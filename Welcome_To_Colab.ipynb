# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagyashree-sudo/Task5/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dataset=pd.read_csv("/content/students.csv")

x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values

from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_estimators=50,random_state=1)
model.fit(x,y)

new_student=[[7,82,76]]
prediction=regressor.predict(new_student)
print("prediction Final Score:",prediction)
X_hours=dataset.iloc[:,1].values
y_grid=np.arange(np.min(X_hours),np.max(X_hours),0.1).reshape(-1,1)
y_pred = [model.predict([[h[0],80,75]])for h in x_grid]
plt.scatter(dataset.iloc[:,0],y)
plt.plot(x_grid,y_pred)
plt.title("Random Forest Regression Example")
plt.xlabel("Hours studied")
plt.ylabel("Final Score")
plt.show()
# Out:
# prediction Final Score: [78.72]
